# %% [markdown]
# # LoRa® & LoRaWAN® Frames facts ans stats
#
# Author: Didier DONSEZ, Université Grenoble Alpes.

# %%
import pandas as pd

# %%
dataup = pd.read_csv('msg-20240707-lite-dataup.csv')
dataup.head()
# Out:
#   modulation codeRate  frequency  _datarate  rssi  loRaSNR    _esp crcStatus  \
# 0       LORA      4/5  868100000        5.0   -67     14.0  -67.17    CRC_OK
# 1       LORA      4/5  868100000        5.0   -66     14.0  -66.17    CRC_OK
# 2       LORA      4/5  867500000        5.0  -103      5.8 -104.01    CRC_OK
# 3       LORA      4/5  867500000        5.0  -101     -6.8 -108.62    CRC_OK
# 4       LORA      4/5  867900000        5.0   -88     10.2  -88.40    CRC_OK
#
#           gatewayID        _packet.mtype  ... _packet.confirmed _packet.fport  \
# 0  00800000a000531a  Unconfirmed Data Up  ...             False           6.0
# 1  00800000a000531a  Unconfirmed Data Up  ...             False           6.0
# 2  008000000001c308  Unconfirmed Data Up  ...             False           5.0
# 3  7076ff005605022f  Unconfirmed Data Up  ...             False           5.0
# 4  7076ff0056050437    Confirmed Data Up  ...              True           1.0
#
# ...

# %%
dataup.describe()
# Out:
#           frequency     _datarate          rssi       loRaSNR          _esp  \
# count  2.472953e+06  2.460613e+06  2.472953e+06  2.472953e+06  2.472953e+06
# mean   8.759278e+08  3.079125e+00 -1.085577e+02 -2.602929e+00 -1.147439e+02
# std    1.135253e+08  2.229084e+00  1.247268e+01  8.932244e+00  1.608784e+01
# min    8.651000e+08  0.000000e+00 -1.410000e+02 -2.500000e+01 -1.505100e+02
# 25%    8.675000e+08  0.000000e+00 -1.170000e+02 -9.000000e+00 -1.260800e+02
# 50%    8.679000e+08  5.000000e+00 -1.120000e+02 -2.500000e+00 -1.174600e+02
# 75%    8.683000e+08  5.000000e+00 -1.050000e+02  5.000000e+00 -1.071900e+02
# max    2.479000e+09  6.000000e+00  1.190000e+02  1.500000e+01  1.150900e+02
#
#        _packet.fcnt  _packet.fport  _packet.payloadLen  _packet.phyPayloadLen  \
# count  2.472953e+06   2.466870e+06        2.472953e+06           2.472953e+06
# mean   1.810131e+04   1.408347e+01        1.764781e+01           3.092509e+01
# ...
